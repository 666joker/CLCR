# %%
# !bash eval_aste_laptop14.sh
# Out:
# + export CUDA_VISIBLE_DEVICES=0
# + CUDA_VISIBLE_DEVICES=0
# + declare -A TASK_DATA
# + TASK_DATA[aste]=laptop14
# + cd src
# + for TASK in aste
# + for DATA in ${TASK_DATA[${TASK}]}
# + for DATA_RATIO in 1.0
# + for SEED in 151
# + for K in 6
# + INFER_PATH=6
# + CTRL_TOKEN=post
# + OUT_DIR=../output/aste/laptop14/top6_post_data1.0_seed151
# + TEST_OUTPUT_DIR=../test_output/aste/laptop14/top6_post_data1.0_seed151
# + mkdir -p ../output/aste/laptop14/top6_post_data1.0_seed151
# + mkdir -p ../test_output/aste/laptop14/top6_post_data1.0_seed151
# ...

# %%
# !bash eval_aste_rest14.sh
# Out:
# + export CUDA_VISIBLE_DEVICES=0
# + CUDA_VISIBLE_DEVICES=0
# + declare -A TASK_DATA
# + TASK_DATA[aste]=rest14
# + cd src
# + for TASK in aste
# + for DATA in ${TASK_DATA[${TASK}]}
# + for DATA_RATIO in 1.0
# + for SEED in 23
# + for K in 6
# + INFER_PATH=6
# + CTRL_TOKEN=post
# + OUT_DIR=../output/aste/rest14/top6_post_data1.0_seed23
# + TEST_OUTPUT_DIR=../test_output/aste/rest14/top6_post_data1.0_seed23
# + mkdir -p ../output/aste/rest14/top6_post_data1.0_seed23
# + mkdir -p ../test_output/aste/rest14/top6_post_data1.0_seed23
# + tee ../test_output/aste/rest14/top6_post_data1.0_seed23/test.log
# ...

# %%
# !bash eval_aste_rest15.sh
# Out:
# + export CUDA_VISIBLE_DEVICES=0
# + CUDA_VISIBLE_DEVICES=0
# + declare -A TASK_DATA
# + TASK_DATA[aste]=rest15
# + cd src
# + for TASK in aste
# + for DATA in ${TASK_DATA[${TASK}]}
# + for DATA_RATIO in 1.0
# + for SEED in 9
# + for K in 6
# + INFER_PATH=6
# + CTRL_TOKEN=post
# + OUT_DIR=../output/aste/rest15/top6_post_data1.0_seed9
# + TEST_OUTPUT_DIR=../test_output/aste/rest15/top6_post_data1.0_seed9
# + mkdir -p ../output/aste/rest15/top6_post_data1.0_seed9
# + mkdir -p ../test_output/aste/rest15/top6_post_data1.0_seed9
# + tee ../test_output/aste/rest15/top6_post_data1.0_seed9/test.log
# ...

# %%
# !bash eval_aste_rest16.sh
# Out:
# + export CUDA_VISIBLE_DEVICES=0
# + CUDA_VISIBLE_DEVICES=0
# + declare -A TASK_DATA
# + TASK_DATA[aste]=rest16
# + cd src
# + for TASK in aste
# + for DATA in ${TASK_DATA[${TASK}]}
# + for DATA_RATIO in 1.0
# + for SEED in 5
# + for K in 6
# + INFER_PATH=6
# + CTRL_TOKEN=post
# + OUT_DIR=../output/aste/rest16/top6_post_data1.0_seed5
# + TEST_OUTPUT_DIR=../test_output/aste/rest16/top6_post_data1.0_seed5
# + mkdir -p ../output/aste/rest16/top6_post_data1.0_seed5
# + mkdir -p ../test_output/aste/rest16/top6_post_data1.0_seed5
# ...
